# %%
import pandas as pd

df = pd.read_csv('postings.csv')

display(df)
# Out:
#                                              job_title  \
# 0                                      Data Engineer 2
# 1                                  Staff Data Engineer
# 2                 Senior Data Engineer, Public Company
# 3                 Senior Data Engineer, Public Company
# 4         Senior Systems Engineer, Azure Data Platform
# ...                                                ...
# 6020                        Senior Oracle Data Analyst
# 6021                           Data Governance Analyst
# 6022                  Energy Data and Forecast Analyst
# 6023                             Junior Data Scientist
# 6024  Lead Data Engineer (Python, SQL, Cloud Engineer)
#
#                       company                            job_location  \
# 0                Cook Medical                         Bloomington, IN
# 1     Recruiting from Scratch                         Bloomington, IN
# 2     Recruiting from Scratch                         Bloomington, IN
# ...

# %%
display(df.columns)
# Out:
# Index(['job_title', 'company', 'job_location', 'job_link', 'first_seen',
#        'search_city', 'search_country', 'job level', 'job_type', 'job_summary',
#        'job_skills'],
#       dtype='object')
